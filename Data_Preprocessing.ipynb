# %%
# !git clone https://github.com/gucorpling/amalgum.git
# Out:
# Cloning into 'amalgum'...
# remote: Enumerating objects: 148871, done.
# remote: Counting objects: 100% (7860/7860), done.
# remote: Compressing objects: 100% (1845/1845), done.
# remote: Total 148871 (delta 6020), reused 7819 (delta 6014), pack-reused 141011 (from 1)
# Receiving objects: 100% (148871/148871), 714.55 MiB | 21.57 MiB/s, done.
# Resolving deltas: 100% (101358/101358), done.
# Updating files: 100% (24540/24540), done.

# %%
import os
import re
import random
import pandas as pd
import nltk
from collections import Counter

# %%
def extract_tokens_from_conllu(filepath):
    tokens = []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            if not line.startswith('#') and line.strip():
                parts = line.strip().split('\t')
                if len(parts) >= 2 and '.' not in parts[0]:
                    tokens.append(parts[1])
    return tokens

base_dir = "amalgum/amalgum"
genres = {
    "fiction": 350,
    "bio": 350
}
max_total_files = sum(genres.values())
all_tokens = []

print("Selected files and sizes (in KB):")
total_kb = 0

random.seed(42)

for genre, file_limit in genres.items():
    genre_dir = os.path.join(base_dir, genre, "dep")
    conllu_files = [f for f in os.listdir(genre_dir) if f.endswith(".conllu")]
    selected_files = random.sample(conllu_files, file_limit)

    for file in selected_files:
        filepath = os.path.join(genre_dir, file)
        file_size_kb = os.path.getsize(filepath) / 1024
        total_kb += file_size_kb

        print(f"{file} — {file_size_kb:.2f} KB")

        tokens = extract_tokens_from_conllu(filepath)
        all_tokens.extend(tokens)

raw_text = ' '.join(all_tokens)
print(f"\nTotal data size: {total_kb:.2f} KB ({len(all_tokens)} tokens)")
# Out:
# Selected files and sizes (in KB):
# AMALGUM_fiction_hans.conllu — 86.00 KB
# AMALGUM_fiction_helium.conllu — 70.36 KB
# AMALGUM_fiction_perry.conllu — 76.60 KB
# AMALGUM_fiction_hilarius.conllu — 79.00 KB
# AMALGUM_fiction_van.conllu — 77.69 KB
# AMALGUM_fiction_mansoul.conllu — 78.14 KB
# AMALGUM_fiction_mapuhi.conllu — 82.31 KB
# AMALGUM_fiction_residencia.conllu — 76.87 KB
# AMALGUM_fiction_flirt.conllu — 86.27 KB
# AMALGUM_fiction_amulet.conllu — 81.68 KB
# AMALGUM_fiction_huckleberry.conllu — 81.36 KB
# AMALGUM_fiction_nugget.conllu — 80.15 KB
# AMALGUM_fiction_lenape.conllu — 76.17 KB
# AMALGUM_fiction_diana.conllu — 78.64 KB
# AMALGUM_fiction_shadow.conllu — 74.25 KB
# AMALGUM_fiction_dynamiter.conllu — 85.07 KB
# AMALGUM_fiction_harney.conllu — 80.48 KB
# AMALGUM_fiction_goriot.conllu — 78.92 KB
# AMALGUM_fiction_desplein.conllu — 75.28 KB
# AMALGUM_fiction_gentleman.conllu — 85.72 KB
# AMALGUM_fiction_swift.conllu — 79.88 KB
# AMALGUM_fiction_casterbridge.conllu — 78.78 KB
# AMALGUM_fiction_limberlost.conllu — 82.60 KB
# AMALGUM_fiction_rodney.conllu — 87.13 KB
# AMALGUM_fiction_forest.conllu — 77.21 KB
# AMALGUM_fiction_damon.conllu — 83.38 KB
# AMALGUM_fiction_jerry.conllu — 75.32 KB
# AMALGUM_fiction_moon.conllu — 88.88 KB
# AMALGUM_fiction_monseigneur.conllu — 79.07 KB
# AMALGUM_fiction_mates.conllu — 88.12 KB
# AMALGUM_fiction_langeais.conllu — 71.91 KB
# AMALGUM_fiction_tales.conllu — 76.31 KB
# AMALGUM_fiction_holmes.conllu — 77.95 KB
# AMALGUM_fiction_tale.conllu — 79.34 KB
# AMALGUM_fiction_lord.conllu — 74.94 KB
# AMALGUM_fiction_scarlet.conllu — 82.07 KB
# AMALGUM_fiction_cedars.conllu — 78.58 KB
# AMALGUM_fiction_pres.conllu — 82.90 KB
# AMALGUM_fiction_carl.conllu — 77.34 KB
# AMALGUM_fiction_baseball.conllu — 85.59 KB
# AMALGUM_fiction_crossing.conllu — 82.16 KB
# AMALGUM_fiction_flambeau.conllu — 77.58 KB
# AMALGUM_fiction_sage.conllu — 76.09 KB
# AMALGUM_fiction_ambassadors.conllu — 81.56 KB
# AMALGUM_fiction_bhaer.conllu — 75.96 KB
# AMALGUM_fiction_yeobright.conllu — 88.08 KB
# AMALGUM_fiction_prairie.conllu — 74.50 KB
# AMALGUM_fiction_edward.conllu — 85.42 KB
# AMALGUM_fiction_otto.conllu — 80.67 KB
# AMALGUM_fiction_zane.conllu — 76.04 KB
# AMALGUM_fiction_bobbsey.conllu — 88.96 KB
# AMALGUM_fiction_polly.conllu — 80.21 KB
# AMALGUM_fiction_ulrich.conllu — 80.87 KB
# AMALGUM_fiction_redfern.conllu — 83.82 KB
# AMALGUM_fiction_gloom.conllu — 71.29 KB
# AMALGUM_fiction_wharton.conllu — 81.82 KB
# AMALGUM_fiction_moran.conllu — 86.77 KB
# AMALGUM_fiction_theron.conllu — 81.02 KB
# AMALGUM_fiction_elinor.conllu — 88.43 KB
# AMALGUM_fiction_submarine.conllu — 81.47 KB
# AMALGUM_fiction_ransome.conllu — 79.17 KB
# AMALGUM_fiction_phorenice.conllu — 75.51 KB
# AMALGUM_fiction_yates.conllu — 86.58 KB
# AMALGUM_fiction_tom.conllu — 81.38 KB
# AMALGUM_fiction_yoke.conllu — 34.30 KB
# AMALGUM_fiction_sara.conllu — 79.03 KB
# AMALGUM_fiction_veiller.conllu — 77.14 KB
# AMALGUM_fiction_freckles.conllu — 87.04 KB
# AMALGUM_fiction_goro.conllu — 80.30 KB
# AMALGUM_fiction_allan.conllu — 85.46 KB
# AMALGUM_fiction_spook.conllu — 86.89 KB
# AMALGUM_fiction_rock.conllu — 77.78 KB
# AMALGUM_fiction_bunner.conllu — 77.03 KB
# AMALGUM_fiction_customs.conllu — 78.27 KB
# AMALGUM_fiction_jungle.conllu — 89.96 KB
# AMALGUM_fiction_marshalsea.conllu — 75.23 KB
# AMALGUM_fiction_hearth.conllu — 77.47 KB
# AMALGUM_fiction_traveler.conllu — 83.86 KB
# AMALGUM_fiction_emil.conllu — 81.51 KB
# AMALGUM_fiction_curiosity.conllu — 82.93 KB
# AMALGUM_fiction_outcast.conllu — 80.22 KB
# AMALGUM_fiction_bookshop.conllu — 76.33 KB
# AMALGUM_fiction_howe.conllu — 78.51 KB
# AMALGUM_fiction_wyllis.conllu — 73.21 KB
# AMALGUM_fiction_foster.conllu — 78.52 KB
# AMALGUM_fiction_anne.conllu — 78.88 KB
# AMALGUM_fiction_touchstone.conllu — 84.07 KB
# AMALGUM_fiction_tramp.conllu — 87.85 KB
# AMALGUM_fiction_billy.conllu — 84.81 KB
# AMALGUM_fiction_typhoon.conllu — 78.57 KB
# AMALGUM_fiction_woes.conllu — 80.99 KB
# AMALGUM_fiction_harry.conllu — 83.41 KB
# AMALGUM_fiction_korak.conllu — 81.99 KB
# AMALGUM_fiction_adventure.conllu — 73.00 KB
# AMALGUM_fiction_mansion.conllu — 76.51 KB
# AMALGUM_fiction_madding.conllu — 85.34 KB
# AMALGUM_fiction_lookut.conllu — 86.79 KB
# AMALGUM_fiction_tarzan.conllu — 70.72 KB
# AMALGUM_fiction_carpet.conllu — 86.83 KB
# AMALGUM_fiction_vasili.conllu — 79.22 KB
# AMALGUM_fiction_tide.conllu — 72.62 KB
# AMALGUM_fiction_sciatti.conllu — 81.64 KB
# AMALGUM_fiction_mucker.conllu — 86.95 KB
# AMALGUM_fiction_dream.conllu — 77.03 KB
# AMALGUM_fiction_carol.conllu — 75.22 KB
# AMALGUM_fiction_apes.conllu — 73.11 KB
# AMALGUM_fiction_guy.conllu — 78.29 KB
# AMALGUM_fiction_tope.conllu — 84.10 KB
# AMALGUM_fiction_chuzzlewit.conllu — 79.73 KB
# AMALGUM_fiction_dorian.conllu — 77.24 KB
# AMALGUM_fiction_anthem.conllu — 80.38 KB
# AMALGUM_fiction_roderick.conllu — 88.48 KB
# AMALGUM_fiction_lollies.conllu — 82.67 KB
# AMALGUM_fiction_una.conllu — 90.17 KB
# AMALGUM_fiction_margaret.conllu — 76.23 KB
# AMALGUM_fiction_norman.conllu — 74.34 KB
# AMALGUM_fiction_andes.conllu — 82.13 KB
# AMALGUM_fiction_raffles.conllu — 81.80 KB
# AMALGUM_fiction_beatrix.conllu — 76.34 KB
# AMALGUM_fiction_cadignan.conllu — 77.07 KB
# AMALGUM_fiction_fauntleroy.conllu — 76.92 KB
# AMALGUM_fiction_alstyne.conllu — 74.43 KB
# AMALGUM_fiction_wrecker.conllu — 73.70 KB
# AMALGUM_fiction_ruling.conllu — 79.21 KB
# AMALGUM_fiction_arabella.conllu — 73.36 KB
# AMALGUM_fiction_freindship.conllu — 75.50 KB
# AMALGUM_fiction_freya.conllu — 79.55 KB
# AMALGUM_fiction_novelized.conllu — 76.56 KB
# AMALGUM_fiction_ivanovna.conllu — 86.27 KB
# AMALGUM_fiction_gulliver.conllu — 73.58 KB
# AMALGUM_fiction_inga.conllu — 80.51 KB
# AMALGUM_fiction_erma.conllu — 75.88 KB
# AMALGUM_fiction_nephi.conllu — 75.58 KB
# AMALGUM_fiction_vereker.conllu — 74.09 KB
# AMALGUM_fiction_overt.conllu — 78.57 KB
# AMALGUM_fiction_bridge.conllu — 80.91 KB
# AMALGUM_fiction_puck.conllu — 81.79 KB
# AMALGUM_fiction_frances.conllu — 81.66 KB
# AMALGUM_fiction_moreau.conllu — 78.16 KB
# AMALGUM_fiction_melmoth.conllu — 76.28 KB
# AMALGUM_fiction_gladys.conllu — 79.76 KB
# AMALGUM_fiction_emerald.conllu — 74.93 KB
# AMALGUM_fiction_violists.conllu — 76.66 KB
# AMALGUM_fiction_horde.conllu — 73.78 KB
# AMALGUM_fiction_professor.conllu — 81.72 KB
# AMALGUM_fiction_tirant.conllu — 82.44 KB
# AMALGUM_fiction_thy.conllu — 73.63 KB
# AMALGUM_fiction_hoopdriver.conllu — 86.60 KB
# AMALGUM_fiction_elixir.conllu — 70.76 KB
# AMALGUM_fiction_newman.conllu — 80.87 KB
# AMALGUM_fiction_coxon.conllu — 82.81 KB
# AMALGUM_fiction_elfride.conllu — 82.63 KB
# AMALGUM_fiction_slosson.conllu — 82.97 KB
# AMALGUM_fiction_salammbo.conllu — 74.83 KB
# AMALGUM_fiction_sleeper.conllu — 82.39 KB
# AMALGUM_fiction_dope.conllu — 85.43 KB
# AMALGUM_fiction_hawser.conllu — 74.66 KB
# AMALGUM_fiction_lys.conllu — 71.28 KB
# AMALGUM_fiction_dunlap.conllu — 88.91 KB
# AMALGUM_fiction_muldoon.conllu — 81.27 KB
# AMALGUM_fiction_claus.conllu — 76.22 KB
# AMALGUM_fiction_wolf.conllu — 90.11 KB
# AMALGUM_fiction_wrongs.conllu — 76.33 KB
# AMALGUM_fiction_pennycherry.conllu — 85.40 KB
# AMALGUM_fiction_babbitt.conllu — 85.03 KB
# AMALGUM_fiction_artagnan.conllu — 84.67 KB
# AMALGUM_fiction_twi.conllu — 81.46 KB
# AMALGUM_fiction_zeus.conllu — 85.34 KB
# AMALGUM_fiction_persuasion.conllu — 81.75 KB
# AMALGUM_fiction_halsey.conllu — 77.89 KB
# AMALGUM_fiction_reporter.conllu — 79.11 KB
# AMALGUM_fiction_angus.conllu — 78.31 KB
# AMALGUM_fiction_duane.conllu — 82.15 KB
# AMALGUM_fiction_malefactor.conllu — 88.30 KB
# AMALGUM_fiction_tuppence.conllu — 89.13 KB
# AMALGUM_fiction_eaven.conllu — 80.58 KB
# AMALGUM_fiction_crusoe.conllu — 74.31 KB
# AMALGUM_fiction_sagoths.conllu — 79.18 KB
# AMALGUM_fiction_settlers.conllu — 74.71 KB
# AMALGUM_fiction_hon.conllu — 78.05 KB
# AMALGUM_fiction_rougemont.conllu — 84.14 KB
# AMALGUM_fiction_belding.conllu — 76.54 KB
# AMALGUM_fiction_cupid.conllu — 85.94 KB
# AMALGUM_fiction_twain.conllu — 80.44 KB
# AMALGUM_fiction_davy.conllu — 81.44 KB
# AMALGUM_fiction_reade.conllu — 89.59 KB
# AMALGUM_fiction_tann.conllu — 74.41 KB
# AMALGUM_fiction_pethel.conllu — 78.49 KB
# AMALGUM_fiction_electric.conllu — 80.90 KB
# AMALGUM_fiction_harvester.conllu — 85.75 KB
# AMALGUM_fiction_romanticism.conllu — 69.82 KB
# AMALGUM_fiction_purse.conllu — 77.45 KB
# AMALGUM_fiction_batard.conllu — 77.16 KB
# AMALGUM_fiction_trot.conllu — 71.13 KB
# AMALGUM_fiction_renouard.conllu — 90.26 KB
# AMALGUM_fiction_howard.conllu — 78.79 KB
# AMALGUM_fiction_indian.conllu — 84.62 KB
# AMALGUM_fiction_diameter.conllu — 73.32 KB
# AMALGUM_fiction_disputing.conllu — 77.60 KB
# AMALGUM_fiction_loring.conllu — 71.76 KB
# AMALGUM_fiction_dannie.conllu — 93.67 KB
# AMALGUM_fiction_poison.conllu — 79.43 KB
# AMALGUM_fiction_sofa.conllu — 78.52 KB
# AMALGUM_fiction_wuthering.conllu — 84.02 KB
# AMALGUM_fiction_snow.conllu — 79.40 KB
# AMALGUM_fiction_mcteague.conllu — 84.01 KB
# AMALGUM_fiction_penrod.conllu — 78.97 KB
# AMALGUM_fiction_karenin.conllu — 76.48 KB
# AMALGUM_fiction_pantagruel.conllu — 94.90 KB
# AMALGUM_fiction_ocean.conllu — 74.09 KB
# AMALGUM_fiction_akinosuke.conllu — 80.48 KB
# AMALGUM_fiction_copperfield.conllu — 82.70 KB
# AMALGUM_fiction_rolf.conllu — 75.60 KB
# AMALGUM_fiction_minded.conllu — 72.79 KB
# AMALGUM_fiction_mitchell.conllu — 77.64 KB
# AMALGUM_fiction_twins.conllu — 81.44 KB
# AMALGUM_fiction_johnny.conllu — 80.13 KB
# AMALGUM_fiction_bunyan.conllu — 81.14 KB
# AMALGUM_fiction_mcchesney.conllu — 77.90 KB
# AMALGUM_fiction_styles.conllu — 89.10 KB
# AMALGUM_fiction_scrooge.conllu — 83.22 KB
# AMALGUM_fiction_trades.conllu — 75.94 KB
# AMALGUM_fiction_rawdon.conllu — 85.32 KB
# AMALGUM_fiction_pompey.conllu — 75.71 KB
# AMALGUM_fiction_daddy.conllu — 79.23 KB
# AMALGUM_fiction_brooding.conllu — 71.52 KB
# AMALGUM_fiction_desert.conllu — 80.90 KB
# AMALGUM_fiction_antonia.conllu — 78.26 KB
# AMALGUM_fiction_violet.conllu — 79.95 KB
# AMALGUM_fiction_mildred.conllu — 84.62 KB
# AMALGUM_fiction_thorpe.conllu — 75.15 KB
# AMALGUM_fiction_highcamp.conllu — 78.79 KB
# AMALGUM_fiction_wonderful.conllu — 74.99 KB
# AMALGUM_fiction_harley.conllu — 81.05 KB
# AMALGUM_fiction_herodias.conllu — 78.27 KB
# AMALGUM_fiction_quatermain.conllu — 80.53 KB
# AMALGUM_fiction_alfred.conllu — 97.97 KB
# AMALGUM_fiction_nickleby.conllu — 82.58 KB
# AMALGUM_fiction_explanation.conllu — 79.24 KB
# AMALGUM_fiction_sergius.conllu — 91.80 KB
# AMALGUM_fiction_adams.conllu — 98.87 KB
# AMALGUM_fiction_dombey.conllu — 72.78 KB
# AMALGUM_fiction_boyd.conllu — 88.45 KB
# AMALGUM_fiction_cavor.conllu — 86.28 KB
# AMALGUM_fiction_eva.conllu — 83.10 KB
# AMALGUM_fiction_firs.conllu — 82.81 KB
# AMALGUM_fiction_pinocchio.conllu — 79.79 KB
# AMALGUM_fiction_kai.conllu — 78.76 KB
# AMALGUM_fiction_merton.conllu — 82.81 KB
# AMALGUM_fiction_weng.conllu — 76.87 KB
# AMALGUM_fiction_scuddamore.conllu — 73.79 KB
# AMALGUM_fiction_shaggy.conllu — 81.52 KB
# AMALGUM_fiction_genevieve.conllu — 82.55 KB
# AMALGUM_fiction_stroeve.conllu — 83.52 KB
# AMALGUM_fiction_phantom.conllu — 83.78 KB
# AMALGUM_fiction_alice.conllu — 87.71 KB
# AMALGUM_fiction_marie.conllu — 77.83 KB
# AMALGUM_fiction_sawyer.conllu — 83.71 KB
# AMALGUM_fiction_jermyn.conllu — 94.41 KB
# AMALGUM_fiction_anchored.conllu — 76.51 KB
# AMALGUM_fiction_amateur.conllu — 73.31 KB
# AMALGUM_fiction_grass.conllu — 76.32 KB
# AMALGUM_fiction_scapegoat.conllu — 72.00 KB
# AMALGUM_fiction_mooney.conllu — 76.19 KB
# AMALGUM_fiction_susy.conllu — 84.40 KB
# AMALGUM_fiction_cracksman.conllu — 76.27 KB
# AMALGUM_fiction_catriona.conllu — 73.70 KB
# AMALGUM_fiction_steavens.conllu — 76.40 KB
# AMALGUM_fiction_bertram.conllu — 87.78 KB
# AMALGUM_fiction_patchwork.conllu — 81.14 KB
# AMALGUM_fiction_brushwood.conllu — 70.23 KB
# AMALGUM_fiction_bladesover.conllu — 71.81 KB
# AMALGUM_fiction_cedric.conllu — 77.38 KB
# AMALGUM_fiction_dorothy.conllu — 68.69 KB
# AMALGUM_fiction_rastignac.conllu — 81.95 KB
# AMALGUM_fiction_edie.conllu — 79.60 KB
# AMALGUM_fiction_matthew.conllu — 79.74 KB
# AMALGUM_fiction_ajor.conllu — 71.23 KB
# AMALGUM_fiction_mars.conllu — 69.25 KB
# AMALGUM_fiction_garden.conllu — 73.16 KB
# AMALGUM_fiction_racing.conllu — 84.05 KB
# AMALGUM_fiction_fangs.conllu — 75.67 KB
# AMALGUM_fiction_therese.conllu — 73.64 KB
# AMALGUM_fiction_uncle.conllu — 81.20 KB
# AMALGUM_fiction_gambler.conllu — 78.29 KB
# AMALGUM_fiction_provost.conllu — 72.15 KB
# AMALGUM_fiction_fifth.conllu — 81.18 KB
# AMALGUM_fiction_northanger.conllu — 73.38 KB
# AMALGUM_fiction_sherlock.conllu — 77.05 KB
# AMALGUM_fiction_fanny.conllu — 78.81 KB
# AMALGUM_fiction_schoolmaster.conllu — 79.20 KB
# AMALGUM_fiction_plague.conllu — 70.14 KB
# AMALGUM_fiction_ann.conllu — 98.76 KB
# AMALGUM_fiction_wondrous.conllu — 72.47 KB
# AMALGUM_fiction_mary.conllu — 84.36 KB
# AMALGUM_fiction_consciousness.conllu — 73.39 KB
# AMALGUM_fiction_manon.conllu — 77.04 KB
# AMALGUM_fiction_strange.conllu — 70.73 KB
# AMALGUM_fiction_mansfield.conllu — 82.22 KB
# AMALGUM_fiction_worlds.conllu — 74.56 KB
# AMALGUM_fiction_boarding.conllu — 74.64 KB
# AMALGUM_fiction_girlish.conllu — 81.72 KB
# AMALGUM_fiction_blix.conllu — 82.28 KB
# AMALGUM_fiction_dick.conllu — 74.99 KB
# AMALGUM_fiction_moonstone.conllu — 79.92 KB
# AMALGUM_fiction_heel.conllu — 79.43 KB
# AMALGUM_fiction_bride.conllu — 74.38 KB
# AMALGUM_fiction_lobster.conllu — 76.74 KB
# AMALGUM_fiction_yuh.conllu — 83.12 KB
# AMALGUM_fiction_rob.conllu — 82.98 KB
# AMALGUM_fiction_edith.conllu — 87.30 KB
# AMALGUM_fiction_pan.conllu — 74.57 KB
# AMALGUM_fiction_rode.conllu — 72.93 KB
# AMALGUM_fiction_sketches.conllu — 70.86 KB
# AMALGUM_fiction_princess.conllu — 79.37 KB
# AMALGUM_fiction_monte.conllu — 79.96 KB
# AMALGUM_fiction_greenmantle.conllu — 84.75 KB
# AMALGUM_fiction_fiddler.conllu — 81.89 KB
# AMALGUM_fiction_herland.conllu — 86.38 KB
# AMALGUM_fiction_grose.conllu — 81.24 KB
# AMALGUM_fiction_emma.conllu — 74.38 KB
# AMALGUM_fiction_sieu.conllu — 73.24 KB
# AMALGUM_fiction_zenda.conllu — 75.84 KB
# AMALGUM_fiction_clay.conllu — 74.41 KB
# AMALGUM_fiction_matilda.conllu — 76.67 KB
# AMALGUM_fiction_flat.conllu — 74.73 KB
# AMALGUM_fiction_bradley.conllu — 72.02 KB
# AMALGUM_fiction_fish.conllu — 77.89 KB
# AMALGUM_fiction_claret.conllu — 79.77 KB
# AMALGUM_fiction_dugong.conllu — 81.10 KB
# AMALGUM_fiction_witt.conllu — 70.96 KB
# AMALGUM_fiction_jack.conllu — 88.64 KB
# AMALGUM_fiction_golden.conllu — 75.27 KB
# AMALGUM_fiction_unexpected.conllu — 72.87 KB
# AMALGUM_fiction_luck.conllu — 81.94 KB
# AMALGUM_fiction_canyon.conllu — 72.39 KB
# AMALGUM_fiction_chaka.conllu — 78.97 KB
# AMALGUM_fiction_zaluski.conllu — 82.34 KB
# AMALGUM_fiction_glinda.conllu — 72.60 KB
# AMALGUM_fiction_quarry.conllu — 81.10 KB
# AMALGUM_fiction_bell.conllu — 72.99 KB
# AMALGUM_fiction_sacks.conllu — 86.48 KB
# AMALGUM_fiction_balloon.conllu — 78.81 KB
# AMALGUM_fiction_ghost.conllu — 83.16 KB
# AMALGUM_fiction_gratitude.conllu — 80.49 KB
# AMALGUM_fiction_madeline.conllu — 81.58 KB
# AMALGUM_fiction_thinkers.conllu — 83.78 KB
# AMALGUM_fiction_magic.conllu — 81.29 KB
# AMALGUM_fiction_sis.conllu — 79.74 KB
# AMALGUM_fiction_fawn.conllu — 74.75 KB
# AMALGUM_bio_osman.conllu — 85.14 KB
# AMALGUM_bio_mardin.conllu — 65.23 KB
# AMALGUM_bio_anna.conllu — 82.76 KB
# AMALGUM_bio_langton.conllu — 64.34 KB
# AMALGUM_bio_aguilar.conllu — 45.98 KB
# AMALGUM_bio_beveren.conllu — 52.98 KB
# AMALGUM_bio_firestone.conllu — 49.81 KB
# AMALGUM_bio_gunthorpe.conllu — 69.28 KB
# AMALGUM_bio_bandinelli.conllu — 42.12 KB
# AMALGUM_bio_qua.conllu — 42.16 KB
# AMALGUM_bio_rumlu.conllu — 51.39 KB
# AMALGUM_bio_ghisliero.conllu — 43.79 KB
# AMALGUM_bio_robson.conllu — 56.47 KB
# AMALGUM_bio_hutchins.conllu — 46.51 KB
# AMALGUM_bio_nzewi.conllu — 52.54 KB
# AMALGUM_bio_giambelli.conllu — 66.85 KB
# AMALGUM_bio_lafayette.conllu — 54.55 KB
# AMALGUM_bio_begum.conllu — 64.89 KB
# AMALGUM_bio_polit.conllu — 39.71 KB
# AMALGUM_bio_hawkesworth.conllu — 93.79 KB
# AMALGUM_bio_orthwein.conllu — 53.14 KB
# AMALGUM_bio_spaeth.conllu — 45.04 KB
# AMALGUM_bio_panneels.conllu — 83.00 KB
# AMALGUM_bio_tisquesusa.conllu — 62.77 KB
# AMALGUM_bio_tonti.conllu — 67.32 KB
# AMALGUM_bio_gorkum.conllu — 86.75 KB
# AMALGUM_bio_dee.conllu — 75.05 KB
# AMALGUM_bio_lester.conllu — 43.43 KB
# AMALGUM_bio_gabriel.conllu — 49.54 KB
# AMALGUM_bio_nilsson.conllu — 62.01 KB
# AMALGUM_bio_feltre.conllu — 40.25 KB
# AMALGUM_bio_stanley.conllu — 49.84 KB
# AMALGUM_bio_barksted.conllu — 43.15 KB
# AMALGUM_bio_kongo.conllu — 37.61 KB
# AMALGUM_bio_idris.conllu — 55.97 KB
# AMALGUM_bio_carco.conllu — 59.91 KB
# AMALGUM_bio_petit.conllu — 44.45 KB
# AMALGUM_bio_jenny.conllu — 65.92 KB
# AMALGUM_bio_feng.conllu — 44.31 KB
# AMALGUM_bio_neville.conllu — 80.33 KB
# AMALGUM_bio_may.conllu — 50.67 KB
# AMALGUM_bio_abukhater.conllu — 90.32 KB
# AMALGUM_bio_paulides.conllu — 97.26 KB
# AMALGUM_bio_gil.conllu — 72.00 KB
# AMALGUM_bio_pattar.conllu — 46.54 KB
# AMALGUM_bio_aguado.conllu — 54.25 KB
# AMALGUM_bio_cusack.conllu — 47.14 KB
# AMALGUM_bio_swie.conllu — 69.97 KB
# AMALGUM_bio_ordubadi.conllu — 68.42 KB
# AMALGUM_bio_black.conllu — 46.61 KB
# AMALGUM_bio_bergavenny.conllu — 55.45 KB
# AMALGUM_bio_koukoudeas.conllu — 46.95 KB
# AMALGUM_bio_parson.conllu — 78.95 KB
# AMALGUM_bio_carbonariis.conllu — 87.27 KB
# AMALGUM_bio_scorpia.conllu — 61.67 KB
# AMALGUM_bio_inge.conllu — 57.02 KB
# AMALGUM_bio_gregory.conllu — 51.13 KB
# AMALGUM_bio_james.conllu — 67.00 KB
# AMALGUM_bio_bear.conllu — 88.60 KB
# AMALGUM_bio_ranelagh.conllu — 44.90 KB
# AMALGUM_bio_freemason.conllu — 89.99 KB
# AMALGUM_bio_gawdy.conllu — 47.34 KB
# AMALGUM_bio_schwenckfeld.conllu — 75.95 KB
# AMALGUM_bio_silva.conllu — 74.99 KB
# AMALGUM_bio_headwards.conllu — 53.13 KB
# AMALGUM_bio_family.conllu — 62.67 KB
# AMALGUM_bio_garcia.conllu — 79.40 KB
# AMALGUM_bio_kissick.conllu — 46.62 KB
# AMALGUM_bio_imran.conllu — 43.75 KB
# AMALGUM_bio_ii.conllu — 48.99 KB
# AMALGUM_bio_boahene.conllu — 57.45 KB
# AMALGUM_bio_oostsanen.conllu — 67.10 KB
# AMALGUM_bio_khizan.conllu — 44.94 KB
# AMALGUM_bio_francine.conllu — 85.05 KB
# AMALGUM_bio_whisenant.conllu — 44.21 KB
# AMALGUM_bio_mariano.conllu — 70.91 KB
# AMALGUM_bio_wingfield.conllu — 48.05 KB
# AMALGUM_bio_bearcrofts.conllu — 54.87 KB
# AMALGUM_bio_prattichizzo.conllu — 46.82 KB
# AMALGUM_bio_liu.conllu — 44.72 KB
# AMALGUM_bio_armani.conllu — 64.68 KB
# AMALGUM_bio_horner.conllu — 47.97 KB
# AMALGUM_bio_grdan.conllu — 62.61 KB
# AMALGUM_bio_broadhurst.conllu — 43.50 KB
# AMALGUM_bio_malankara.conllu — 79.58 KB
# AMALGUM_bio_louvre.conllu — 56.93 KB
# AMALGUM_bio_vednita.conllu — 58.27 KB
# AMALGUM_bio_rahman.conllu — 61.24 KB
# AMALGUM_bio_charnock.conllu — 59.43 KB
# AMALGUM_bio_porcari.conllu — 41.95 KB
# AMALGUM_bio_claiborne.conllu — 55.63 KB
# AMALGUM_bio_cacique.conllu — 56.26 KB
# AMALGUM_bio_martyrs.conllu — 63.97 KB
# AMALGUM_bio_powell.conllu — 54.17 KB
# AMALGUM_bio_jane.conllu — 56.45 KB
# AMALGUM_bio_manasa.conllu — 57.81 KB
# AMALGUM_bio_navy.conllu — 63.71 KB
# AMALGUM_bio_kulkarni.conllu — 81.97 KB
# AMALGUM_bio_davies.conllu — 49.39 KB
# AMALGUM_bio_kooper.conllu — 47.11 KB
# AMALGUM_bio_kapsas.conllu — 54.05 KB
# AMALGUM_bio_tahir.conllu — 47.81 KB
# AMALGUM_bio_fell.conllu — 40.53 KB
# AMALGUM_bio_v.conllu — 71.53 KB
# AMALGUM_bio_madame.conllu — 37.47 KB
# AMALGUM_bio_ely.conllu — 50.16 KB
# AMALGUM_bio_speakman.conllu — 51.59 KB
# AMALGUM_bio_buganda.conllu — 61.51 KB
# AMALGUM_bio_straas.conllu — 65.13 KB
# AMALGUM_bio_wingina.conllu — 44.33 KB
# AMALGUM_bio_altarpiece.conllu — 61.57 KB
# AMALGUM_bio_abu.conllu — 45.32 KB
# AMALGUM_bio_banda.conllu — 59.62 KB
# AMALGUM_bio_john.conllu — 77.53 KB
# AMALGUM_bio_juanita.conllu — 75.25 KB
# AMALGUM_bio_hatuey.conllu — 58.46 KB
# AMALGUM_bio_iwaniuk.conllu — 62.33 KB
# AMALGUM_bio_peng.conllu — 44.29 KB
# AMALGUM_bio_arran.conllu — 89.19 KB
# AMALGUM_bio_miles.conllu — 65.74 KB
# AMALGUM_bio_dudley.conllu — 49.37 KB
# AMALGUM_bio_bothwell.conllu — 47.56 KB
# AMALGUM_bio_phelips.conllu — 59.79 KB
# AMALGUM_bio_robert.conllu — 78.21 KB
# AMALGUM_bio_colard.conllu — 88.70 KB
# AMALGUM_bio_marziale.conllu — 51.17 KB
# AMALGUM_bio_devaynes.conllu — 58.06 KB
# AMALGUM_bio_stane.conllu — 66.42 KB
# AMALGUM_bio_turner.conllu — 45.88 KB
# AMALGUM_bio_longueval.conllu — 54.20 KB
# AMALGUM_bio_doe.conllu — 80.13 KB
# AMALGUM_bio_weber.conllu — 46.19 KB
# AMALGUM_bio_pasha.conllu — 67.67 KB
# AMALGUM_bio_heather.conllu — 45.62 KB
# AMALGUM_bio_martin.conllu — 77.47 KB
# AMALGUM_bio_english.conllu — 60.19 KB
# AMALGUM_bio_wilkins.conllu — 43.15 KB
# AMALGUM_bio_gelves.conllu — 72.92 KB
# AMALGUM_bio_vongsa.conllu — 75.56 KB
# AMALGUM_bio_paulet.conllu — 79.40 KB
# AMALGUM_bio_dyche.conllu — 58.33 KB
# AMALGUM_bio_schobert.conllu — 53.01 KB
# AMALGUM_bio_bey.conllu — 53.32 KB
# AMALGUM_bio_short.conllu — 46.81 KB
# AMALGUM_bio_padilla.conllu — 46.52 KB
# AMALGUM_bio_blyth.conllu — 59.23 KB
# AMALGUM_bio_hales.conllu — 55.65 KB
# AMALGUM_bio_rossetto.conllu — 49.97 KB
# AMALGUM_bio_seaman.conllu — 66.23 KB
# AMALGUM_bio_benson.conllu — 53.01 KB
# AMALGUM_bio_pole.conllu — 40.31 KB
# AMALGUM_bio_tupoumoheofo.conllu — 99.54 KB
# AMALGUM_bio_huipa.conllu — 60.53 KB
# AMALGUM_bio_dieupart.conllu — 63.79 KB
# AMALGUM_bio_marimba.conllu — 86.10 KB
# AMALGUM_bio_bilal.conllu — 44.67 KB
# AMALGUM_bio_morgan.conllu — 101.96 KB
# AMALGUM_bio_abdi.conllu — 66.47 KB
# AMALGUM_bio_trebizond.conllu — 49.21 KB
# AMALGUM_bio_knivet.conllu — 42.76 KB
# AMALGUM_bio_boyleau.conllu — 54.31 KB
# AMALGUM_bio_vancouver.conllu — 60.67 KB
# AMALGUM_bio_kahan.conllu — 64.31 KB
# AMALGUM_bio_varma.conllu — 62.45 KB
# AMALGUM_bio_ruddy.conllu — 111.52 KB
# AMALGUM_bio_capital.conllu — 48.48 KB
# AMALGUM_bio_roncalli.conllu — 58.16 KB
# AMALGUM_bio_walker.conllu — 62.84 KB
# AMALGUM_bio_macmanus.conllu — 59.02 KB
# AMALGUM_bio_makarije.conllu — 51.46 KB
# AMALGUM_bio_kartli.conllu — 74.17 KB
# AMALGUM_bio_pelin.conllu — 51.82 KB
# AMALGUM_bio_ibrahim.conllu — 67.72 KB
# AMALGUM_bio_mainerio.conllu — 45.54 KB
# AMALGUM_bio_lebensohn.conllu — 78.92 KB
# AMALGUM_bio_aaron.conllu — 44.08 KB
# AMALGUM_bio_mizrahi.conllu — 46.75 KB
# AMALGUM_bio_ustajlu.conllu — 74.53 KB
# AMALGUM_bio_empress.conllu — 75.09 KB
# AMALGUM_bio_constable.conllu — 55.43 KB
# AMALGUM_bio_cloedt.conllu — 49.55 KB
# AMALGUM_bio_fludd.conllu — 63.87 KB
# AMALGUM_bio_cornet.conllu — 68.53 KB
# AMALGUM_bio_clare.conllu — 51.84 KB
# AMALGUM_bio_said.conllu — 57.20 KB
# AMALGUM_bio_alva.conllu — 66.84 KB
# AMALGUM_bio_elizabeth.conllu — 44.11 KB
# AMALGUM_bio_wyatt.conllu — 60.98 KB
# AMALGUM_bio_kineubenae.conllu — 73.20 KB
# AMALGUM_bio_caris.conllu — 69.35 KB
# AMALGUM_bio_watts.conllu — 46.37 KB
# AMALGUM_bio_wallace.conllu — 49.03 KB
# AMALGUM_bio_curnyn.conllu — 57.29 KB
# AMALGUM_bio_bongiovanni.conllu — 48.54 KB
# AMALGUM_bio_leuhusen.conllu — 44.74 KB
# AMALGUM_bio_greber.conllu — 81.38 KB
# AMALGUM_bio_holley.conllu — 51.78 KB
# AMALGUM_bio_grigoryevich.conllu — 43.34 KB
# AMALGUM_bio_thiruvancheril.conllu — 83.47 KB
# AMALGUM_bio_goetz.conllu — 60.88 KB
# AMALGUM_bio_mullinger.conllu — 51.99 KB
# AMALGUM_bio_kaur.conllu — 44.44 KB
# AMALGUM_bio_cat.conllu — 57.38 KB
# AMALGUM_bio_mahune.conllu — 44.52 KB
# AMALGUM_bio_ormond.conllu — 83.20 KB
# AMALGUM_bio_ghiyas.conllu — 70.47 KB
# AMALGUM_bio_shani.conllu — 71.93 KB
# AMALGUM_bio_maclean.conllu — 50.68 KB
# AMALGUM_bio_stoss.conllu — 77.20 KB
# AMALGUM_bio_yi.conllu — 46.37 KB
# AMALGUM_bio_clench.conllu — 42.67 KB
# AMALGUM_bio_haider.conllu — 48.93 KB
# AMALGUM_bio_bolek.conllu — 49.89 KB
# AMALGUM_bio_dietterlin.conllu — 64.65 KB
# AMALGUM_bio_hristofor.conllu — 80.94 KB
# AMALGUM_bio_michoel.conllu — 63.94 KB
# AMALGUM_bio_abdullah.conllu — 59.69 KB
# AMALGUM_bio_cartagena.conllu — 68.76 KB
# AMALGUM_bio_dolor.conllu — 62.67 KB
# AMALGUM_bio_verges.conllu — 105.56 KB
# AMALGUM_bio_hogan.conllu — 43.92 KB
# AMALGUM_bio_cardinal.conllu — 83.37 KB
# AMALGUM_bio_mallory.conllu — 99.79 KB
# AMALGUM_bio_mustafa.conllu — 62.99 KB
# AMALGUM_bio_blake.conllu — 44.71 KB
# AMALGUM_bio_mason.conllu — 94.95 KB
# AMALGUM_bio_editions.conllu — 80.27 KB
# AMALGUM_bio_drekale.conllu — 50.21 KB
# AMALGUM_bio_jacobsen.conllu — 56.95 KB
# AMALGUM_bio_francis.conllu — 45.78 KB
# AMALGUM_bio_gilligen.conllu — 93.86 KB
# AMALGUM_bio_stockwood.conllu — 69.70 KB
# AMALGUM_bio_maitatsine.conllu — 44.90 KB
# AMALGUM_bio_worcester.conllu — 51.04 KB
# AMALGUM_bio_fian.conllu — 47.31 KB
# AMALGUM_bio_davis.conllu — 75.74 KB
# AMALGUM_bio_zumba.conllu — 63.72 KB
# AMALGUM_bio_huntly.conllu — 51.53 KB
# AMALGUM_bio_trimlestown.conllu — 44.74 KB
# AMALGUM_bio_korsrud.conllu — 54.89 KB
# AMALGUM_bio_chepman.conllu — 50.36 KB
# AMALGUM_bio_pikes.conllu — 81.72 KB
# AMALGUM_bio_ottoman.conllu — 97.97 KB
# AMALGUM_bio_szczytt.conllu — 80.53 KB
# AMALGUM_bio_bannerjee.conllu — 79.08 KB
# AMALGUM_bio_zborowski.conllu — 77.34 KB
# AMALGUM_bio_thani.conllu — 56.89 KB
# AMALGUM_bio_abraham.conllu — 57.05 KB
# AMALGUM_bio_fraunce.conllu — 51.68 KB
# AMALGUM_bio_boki.conllu — 79.98 KB
# AMALGUM_bio_notaras.conllu — 53.76 KB
# AMALGUM_bio_ballet.conllu — 42.71 KB
# AMALGUM_bio_souhait.conllu — 42.68 KB
# AMALGUM_bio_bastidas.conllu — 88.87 KB
# AMALGUM_bio_altham.conllu — 73.60 KB
# AMALGUM_bio_mazzeo.conllu — 43.30 KB
# AMALGUM_bio_mcintosh.conllu — 45.82 KB
# AMALGUM_bio_longwy.conllu — 70.37 KB
# AMALGUM_bio_henry.conllu — 52.00 KB
# AMALGUM_bio_winnick.conllu — 54.52 KB
# AMALGUM_bio_gambi.conllu — 70.79 KB
# AMALGUM_bio_brassington.conllu — 39.38 KB
# AMALGUM_bio_balandin.conllu — 65.12 KB
# AMALGUM_bio_reid.conllu — 63.19 KB
# AMALGUM_bio_kuy.conllu — 62.60 KB
# AMALGUM_bio_lisle.conllu — 93.02 KB
# AMALGUM_bio_lietto.conllu — 44.95 KB
# AMALGUM_bio_bacon.conllu — 71.09 KB
# AMALGUM_bio_linda.conllu — 70.79 KB
# AMALGUM_bio_zamora.conllu — 41.13 KB
# AMALGUM_bio_moscow.conllu — 47.28 KB
# AMALGUM_bio_domhnaill.conllu — 69.01 KB
# AMALGUM_bio_tekla.conllu — 41.18 KB
# AMALGUM_bio_teerlinc.conllu — 61.68 KB
# AMALGUM_bio_wemyss.conllu — 57.08 KB
# AMALGUM_bio_chenhao.conllu — 93.28 KB
# AMALGUM_bio_barnewall.conllu — 71.62 KB
# AMALGUM_bio_veiga.conllu — 49.66 KB
# AMALGUM_bio_gans.conllu — 47.29 KB
# AMALGUM_bio_jaffe.conllu — 46.19 KB
# AMALGUM_bio_mint.conllu — 66.54 KB
# AMALGUM_bio_aragon.conllu — 53.30 KB
# AMALGUM_bio_kaplan.conllu — 50.63 KB
# AMALGUM_bio_anderson.conllu — 44.34 KB
# AMALGUM_bio_wilson.conllu — 61.22 KB
# AMALGUM_bio_kamehameha.conllu — 46.09 KB
# AMALGUM_bio_salcedo.conllu — 49.63 KB
# AMALGUM_bio_calverley.conllu — 56.34 KB
# AMALGUM_bio_geske.conllu — 51.74 KB
# AMALGUM_bio_cologne.conllu — 40.91 KB
# AMALGUM_bio_giovane.conllu — 61.43 KB
# AMALGUM_bio_thompson.conllu — 53.36 KB
# AMALGUM_bio_albernaz.conllu — 66.41 KB
# AMALGUM_bio_komisaruk.conllu — 60.40 KB
# AMALGUM_bio_gould.conllu — 46.25 KB
# AMALGUM_bio_ahn.conllu — 59.81 KB
# AMALGUM_bio_dorschel.conllu — 83.81 KB
# AMALGUM_bio_mateus.conllu — 54.74 KB
# AMALGUM_bio_vernon.conllu — 69.86 KB
# AMALGUM_bio_kuchum.conllu — 57.38 KB
# AMALGUM_bio_manuel.conllu — 69.31 KB
# AMALGUM_bio_green.conllu — 56.17 KB
# AMALGUM_bio_balmaseda.conllu — 63.51 KB
# AMALGUM_bio_hooke.conllu — 68.52 KB
# AMALGUM_bio_barges.conllu — 39.60 KB
# AMALGUM_bio_patterson.conllu — 44.56 KB
# AMALGUM_bio_york.conllu — 43.44 KB
# AMALGUM_bio_halle.conllu — 41.55 KB
# AMALGUM_bio_hiseland.conllu — 48.24 KB
# AMALGUM_bio_landini.conllu — 47.92 KB
# AMALGUM_bio_beg.conllu — 47.32 KB
# AMALGUM_bio_harris.conllu — 45.77 KB
# AMALGUM_bio_frederick.conllu — 84.50 KB
# AMALGUM_bio_ivanova.conllu — 81.51 KB
# AMALGUM_bio_deslondes.conllu — 63.32 KB
# AMALGUM_bio_papadopoulos.conllu — 55.16 KB
# AMALGUM_bio_hall.conllu — 46.79 KB
# AMALGUM_bio_lohet.conllu — 50.12 KB
# AMALGUM_bio_pally.conllu — 49.16 KB
# AMALGUM_bio_coppin.conllu — 86.66 KB
# AMALGUM_bio_burr.conllu — 49.66 KB
# AMALGUM_bio_mcgrath.conllu — 58.10 KB
# AMALGUM_bio_philip.conllu — 52.98 KB
# AMALGUM_bio_ruttley.conllu — 73.86 KB
# AMALGUM_bio_fenn.conllu — 56.03 KB
# AMALGUM_bio_horseback.conllu — 70.38 KB
# AMALGUM_bio_gilbert.conllu — 43.23 KB
# AMALGUM_bio_williams.conllu — 97.01 KB
# AMALGUM_bio_umoja.conllu — 81.05 KB
# AMALGUM_bio_leger.conllu — 58.32 KB
# AMALGUM_bio_tott.conllu — 62.67 KB
# AMALGUM_bio_pierce.conllu — 60.30 KB
# AMALGUM_bio_kiweewa.conllu — 52.45 KB
# AMALGUM_bio_pmc.conllu — 60.79 KB
# AMALGUM_bio_ferguson.conllu — 77.04 KB
# AMALGUM_bio_carr.conllu — 72.87 KB
# AMALGUM_bio_bestami.conllu — 49.46 KB
# AMALGUM_bio_athens.conllu — 42.96 KB
# AMALGUM_bio_fiesco.conllu — 50.79 KB
# AMALGUM_bio_bayer.conllu — 76.46 KB
# AMALGUM_bio_wales.conllu — 67.34 KB
# AMALGUM_bio_driver.conllu — 94.14 KB
# AMALGUM_bio_bullingham.conllu — 42.49 KB
# AMALGUM_bio_brooke.conllu — 44.55 KB
# AMALGUM_bio_powel.conllu — 41.42 KB
# AMALGUM_bio_lattes.conllu — 45.89 KB
# AMALGUM_bio_persdotter.conllu — 68.66 KB
# AMALGUM_bio_pincus.conllu — 51.00 KB
# AMALGUM_bio_donato.conllu — 48.45 KB
# AMALGUM_bio_falkener.conllu — 51.94 KB
#
# Total data size: 48901.58 KB (670075 tokens)

# %%
def merge_apostrophe_tokens(tokens):
    merged_tokens = []
    i = 0
    while i < len(tokens):
        if i < len(tokens) - 1 and tokens[i+1].lower() in {
            "'s", "’s", "'re", "’re", "'ve", "’ve", "'ll", "’ll", "'d", "’d", "'m", "’m", "n't", "n’t"
        }:
            merged = tokens[i] + tokens[i+1]
            merged_tokens.append(merged)
            i += 2
        else:
            merged_tokens.append(tokens[i])
            i += 1
    return merged_tokens

def clean_token(token):
    token = token.lower()
    token = re.sub(r"^[^\w']+|[^\w']+$", "", token)
    if re.fullmatch(r"[a-zA-Z]+'[a-zA-Z]+", token) or token.isalpha():
        return token
    return ""

merged_tokens = merge_apostrophe_tokens(all_tokens)

cleaned_tokens = [clean_token(tok) for tok in merged_tokens if clean_token(tok)]
raw_clean_text = ' '.join(cleaned_tokens)

word_freq = Counter(cleaned_tokens)

# %%
total_words = sum(word_freq.values())
unique_words = len(word_freq)

freq_df = pd.DataFrame(word_freq.items(), columns=['word', 'count'])
freq_df['percent'] = (freq_df['count'] / total_words) * 100
freq_df = freq_df.sort_values(by='count', ascending=False).reset_index(drop=True)

df_size_kb = freq_df.memory_usage(deep=True).sum() / 1024
print(f"DataFrame size: {df_size_kb:.2f} KB")
print(f"Total words: {total_words}")
print(f"Unique words: {unique_words}")
print("\nTop 50 most common words:")
print(freq_df.head(50))
# Out:
# DataFrame size: 2919.45 KB
# Total words: 541570
# Unique words: 36878
#
# Top 50 most common words:
#      word  count   percent
# 0     the  34815  6.428532
# 1      of  20118  3.714755
# 2     and  18232  3.366508
# 3      to  13462  2.485736
# 4      in  12618  2.329893
# 5       a  12191  2.251048
# 6     was   8866  1.637092
# 7      he   7783  1.437118
# 8     his   6041  1.115461
# 9    that   5333  0.984730
# 10      i   4779  0.882434
# 11     as   4469  0.825193
# 12    for   4349  0.803036
# 13     it   4343  0.801928
# 14   with   4151  0.766475
# 15    had   3904  0.720867
# 16     on   3788  0.699448
# 17     at   3485  0.643499
# 18    her   3153  0.582196
# 19     by   2860  0.528094
# 20    she   2859  0.527910
# 21     is   2857  0.527540
# 22   from   2563  0.473254
# 23    but   2485  0.458851
# 24    you   2473  0.456635
# 25    not   2181  0.402718
# 26    him   2105  0.388685
# 27   were   1966  0.363019
# 28     be   1953  0.360618
# 29     an   1913  0.353232
# 30  which   1902  0.351201
# 31   have   1805  0.333290
# 32   this   1766  0.326089
# 33   they   1699  0.313718
# 34    one   1676  0.309471
# 35    all   1531  0.282697
# 36    who   1453  0.268294
# 37     my   1434  0.264786
# 38   when   1351  0.249460
# 39     or   1345  0.248352
# 40     so   1331  0.245767
# 41   been   1329  0.245398
# 42  there   1323  0.244290
# 43   said   1290  0.238196
# 44     me   1189  0.219547
# 45     no   1170  0.216039
# 46  their   1149  0.212161
# 47  would   1032  0.190557
# 48   them   1026  0.189449
# 49    out   1026  0.189449

# %%
from google.colab import drive
drive.mount('/content/drive')

output_path = "/content/drive/MyDrive/NWP/cleaned_text_larger.txt"

with open(output_path, "w", encoding="utf-8") as f:
    f.write(raw_clean_text)

print(f"Saved cleaned text to: {output_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved cleaned text to: /content/drive/MyDrive/NWP/cleaned_text_larger.txt

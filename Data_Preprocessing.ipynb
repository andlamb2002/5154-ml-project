# %%
# AMALGUM Data Source

# !git clone https://github.com/gucorpling/amalgum.git
# Out:
# Cloning into 'amalgum'...
# remote: Enumerating objects: 148871, done.
# remote: Counting objects: 100% (7860/7860), done.
# remote: Compressing objects: 100% (1845/1845), done.
# remote: Total 148871 (delta 6020), reused 7819 (delta 6014), pack-reused 141011 (from 1)
# Receiving objects: 100% (148871/148871), 714.55 MiB | 20.16 MiB/s, done.
# Resolving deltas: 100% (101358/101358), done.
# Updating files: 100% (24540/24540), done.

# %%
# Imports and Setup

import os
import re
import random
import pandas as pd
import nltk
from collections import Counter

random.seed(42)

# %%
# Data Collection

def extract_tokens(filepath):
    tokens = []
    with open(filepath, 'r', encoding='utf-8') as file:
        for line in file:
            if not line.startswith('#') and line.strip():
                parts = line.strip().split('\t')
                if len(parts) >= 2 and '.' not in parts[0]:
                    tokens.append(parts[1])
    return tokens

base_dir = "amalgum/amalgum"
genres = {
    "bio": 150,
    "fiction": 150,
}
max_total_files = sum(genres.values())
all_tokens = []

for genre, file_limit in genres.items():
    genre_dir = os.path.join(base_dir, genre, "dep")
    conllu_files = [f for f in os.listdir(genre_dir) if f.endswith(".conllu")]
    selected_files = random.sample(conllu_files, file_limit)

    for file in selected_files:
        filepath = os.path.join(genre_dir, file)
        print(file)

        tokens = extract_tokens(filepath)
        all_tokens.extend(tokens)

raw_text = ' '.join(all_tokens)

print(f"\nTotal words: {len(all_tokens)}")
print(f"Total characters: {len(raw_text)}")
# Out:
# AMALGUM_bio_komatsu.conllu
# AMALGUM_bio_thompson.conllu
# AMALGUM_bio_robert.conllu
# AMALGUM_bio_lechay.conllu
# AMALGUM_bio_herbert.conllu
# AMALGUM_bio_korsrud.conllu
# AMALGUM_bio_tisquesusa.conllu
# AMALGUM_bio_brassington.conllu
# AMALGUM_bio_legh.conllu
# AMALGUM_bio_jovan.conllu
# AMALGUM_bio_albernaz.conllu
# AMALGUM_bio_bicchi.conllu
# AMALGUM_bio_hakohen.conllu
# AMALGUM_bio_cretaceous.conllu
# AMALGUM_bio_chenhao.conllu
# AMALGUM_bio_gunthorpe.conllu
# AMALGUM_bio_kozinski.conllu
# AMALGUM_bio_dyche.conllu
# AMALGUM_bio_balandin.conllu
# AMALGUM_bio_wadham.conllu
# AMALGUM_bio_freemason.conllu
# AMALGUM_bio_powell.conllu
# AMALGUM_bio_lucombe.conllu
# AMALGUM_bio_wemyss.conllu
# AMALGUM_bio_grainger.conllu
# AMALGUM_bio_rufim.conllu
# AMALGUM_bio_tahir.conllu
# AMALGUM_bio_wallace.conllu
# AMALGUM_bio_malinowski.conllu
# AMALGUM_bio_carco.conllu
# AMALGUM_bio_naotora.conllu
# AMALGUM_bio_blocke.conllu
# AMALGUM_bio_falkener.conllu
# AMALGUM_bio_driver.conllu
# AMALGUM_bio_arca.conllu
# AMALGUM_bio_juanita.conllu
# AMALGUM_bio_lopes.conllu
# AMALGUM_bio_pollaiolo.conllu
# AMALGUM_bio_deslondes.conllu
# AMALGUM_bio_schobert.conllu
# AMALGUM_bio_florence.conllu
# AMALGUM_bio_maclean.conllu
# AMALGUM_bio_gans.conllu
# AMALGUM_bio_phelips.conllu
# AMALGUM_bio_cartagena.conllu
# AMALGUM_bio_forster.conllu
# AMALGUM_bio_fell.conllu
# AMALGUM_bio_makarije.conllu
# AMALGUM_bio_kimbrough.conllu
# AMALGUM_bio_mizrahi.conllu
# AMALGUM_bio_hurley.conllu
# AMALGUM_bio_bass.conllu
# AMALGUM_bio_dennys.conllu
# AMALGUM_bio_kahan.conllu
# AMALGUM_bio_halle.conllu
# AMALGUM_bio_athens.conllu
# AMALGUM_bio_beard.conllu
# AMALGUM_bio_swamigal.conllu
# AMALGUM_bio_gorkum.conllu
# AMALGUM_bio_tanner.conllu
# AMALGUM_bio_jafar.conllu
# AMALGUM_bio_paulet.conllu
# AMALGUM_bio_abdullah.conllu
# AMALGUM_bio_anna.conllu
# AMALGUM_bio_powel.conllu
# AMALGUM_bio_bothwell.conllu
# AMALGUM_bio_carr.conllu
# AMALGUM_bio_collins.conllu
# AMALGUM_bio_whisenant.conllu
# AMALGUM_bio_inge.conllu
# AMALGUM_bio_thirteen.conllu
# AMALGUM_bio_blyth.conllu
# AMALGUM_bio_lemke.conllu
# AMALGUM_bio_granville.conllu
# AMALGUM_bio_calvesi.conllu
# AMALGUM_bio_dorschel.conllu
# AMALGUM_bio_died.conllu
# AMALGUM_bio_quadris.conllu
# AMALGUM_bio_stokoe.conllu
# AMALGUM_bio_ferguson.conllu
# AMALGUM_bio_poglietti.conllu
# AMALGUM_bio_pricasso.conllu
# AMALGUM_bio_lattes.conllu
# AMALGUM_bio_boki.conllu
# AMALGUM_bio_harada.conllu
# AMALGUM_bio_dudley.conllu
# AMALGUM_bio_arran.conllu
# AMALGUM_bio_hotak.conllu
# AMALGUM_bio_feltre.conllu
# AMALGUM_bio_doe.conllu
# AMALGUM_bio_richardson.conllu
# AMALGUM_bio_charlotte.conllu
# AMALGUM_bio_walker.conllu
# AMALGUM_bio_giovane.conllu
# AMALGUM_bio_john.conllu
# AMALGUM_bio_landsberg.conllu
# AMALGUM_bio_benkos.conllu
# AMALGUM_bio_guazzo.conllu
# AMALGUM_bio_liu.conllu
# AMALGUM_bio_jifar.conllu
# AMALGUM_bio_rossetto.conllu
# AMALGUM_bio_gould.conllu
# AMALGUM_bio_ismail.conllu
# AMALGUM_bio_hawkesworth.conllu
# AMALGUM_bio_koldings.conllu
# AMALGUM_bio_babell.conllu
# AMALGUM_bio_kelly.conllu
# AMALGUM_bio_suchorzewski.conllu
# AMALGUM_bio_richard.conllu
# AMALGUM_bio_browne.conllu
# AMALGUM_bio_buglisi.conllu
# AMALGUM_bio_mcintosh.conllu
# AMALGUM_bio_fonseca.conllu
# AMALGUM_bio_cusack.conllu
# AMALGUM_bio_ordubadi.conllu
# AMALGUM_bio_tupoumoheofo.conllu
# AMALGUM_bio_dieupart.conllu
# AMALGUM_bio_rice.conllu
# AMALGUM_bio_karlsdotter.conllu
# AMALGUM_bio_dnb.conllu
# AMALGUM_bio_chater.conllu
# AMALGUM_bio_rahman.conllu
# AMALGUM_bio_bacon.conllu
# AMALGUM_bio_kulkarni.conllu
# AMALGUM_bio_philip.conllu
# AMALGUM_bio_ocllo.conllu
# AMALGUM_bio_mustafa.conllu
# AMALGUM_bio_fenn.conllu
# AMALGUM_bio_basset.conllu
# AMALGUM_bio_ustajlu.conllu
# AMALGUM_bio_gabriel.conllu
# AMALGUM_bio_stuart.conllu
# AMALGUM_bio_ranelagh.conllu
# AMALGUM_bio_fludd.conllu
# AMALGUM_bio_morgan.conllu
# AMALGUM_bio_galliardello.conllu
# AMALGUM_bio_longwy.conllu
# AMALGUM_bio_scobell.conllu
# AMALGUM_bio_firestone.conllu
# AMALGUM_bio_navidi.conllu
# AMALGUM_bio_desmond.conllu
# AMALGUM_bio_mardin.conllu
# AMALGUM_bio_shen.conllu
# AMALGUM_bio_bennet.conllu
# AMALGUM_bio_nemequene.conllu
# AMALGUM_bio_dee.conllu
# AMALGUM_bio_capital.conllu
# AMALGUM_bio_sam.conllu
# AMALGUM_bio_simmes.conllu
# AMALGUM_bio_zamora.conllu
# AMALGUM_fiction_freckles.conllu
# AMALGUM_fiction_wolf.conllu
# AMALGUM_fiction_miriam.conllu
# AMALGUM_fiction_flat.conllu
# AMALGUM_fiction_clay.conllu
# AMALGUM_fiction_princess.conllu
# AMALGUM_fiction_firs.conllu
# AMALGUM_fiction_rose.conllu
# AMALGUM_fiction_worlds.conllu
# AMALGUM_fiction_emerald.conllu
# AMALGUM_fiction_bride.conllu
# AMALGUM_fiction_thinkers.conllu
# AMALGUM_fiction_marlow.conllu
# AMALGUM_fiction_amateur.conllu
# AMALGUM_fiction_edward.conllu
# AMALGUM_fiction_brushwood.conllu
# AMALGUM_fiction_jasper.conllu
# AMALGUM_fiction_sacks.conllu
# AMALGUM_fiction_jack.conllu
# AMALGUM_fiction_fairfax.conllu
# AMALGUM_fiction_bunyan.conllu
# AMALGUM_fiction_moon.conllu
# AMALGUM_fiction_tope.conllu
# AMALGUM_fiction_monseigneur.conllu
# AMALGUM_fiction_turnkey.conllu
# AMALGUM_fiction_middlemarch.conllu
# AMALGUM_fiction_arena.conllu
# AMALGUM_fiction_crossing.conllu
# AMALGUM_fiction_carlton.conllu
# AMALGUM_fiction_andes.conllu
# AMALGUM_fiction_electric.conllu
# AMALGUM_fiction_sketches.conllu
# AMALGUM_fiction_harvester.conllu
# AMALGUM_fiction_fagin.conllu
# AMALGUM_fiction_sagoths.conllu
# AMALGUM_fiction_nickleby.conllu
# AMALGUM_fiction_yates.conllu
# AMALGUM_fiction_lobster.conllu
# AMALGUM_fiction_moll.conllu
# AMALGUM_fiction_laputa.conllu
# AMALGUM_fiction_mooney.conllu
# AMALGUM_fiction_gryce.conllu
# AMALGUM_fiction_outcast.conllu
# AMALGUM_fiction_dorothy.conllu
# AMALGUM_fiction_reef.conllu
# AMALGUM_fiction_grose.conllu
# AMALGUM_fiction_settlers.conllu
# AMALGUM_fiction_elixir.conllu
# AMALGUM_fiction_subtraction.conllu
# AMALGUM_fiction_prairie.conllu
# AMALGUM_fiction_weng.conllu
# AMALGUM_fiction_freya.conllu
# AMALGUM_fiction_erma.conllu
# AMALGUM_fiction_kai.conllu
# AMALGUM_fiction_rastignac.conllu
# AMALGUM_fiction_yoke.conllu
# AMALGUM_fiction_ruling.conllu
# AMALGUM_fiction_reade.conllu
# AMALGUM_fiction_penrod.conllu
# AMALGUM_fiction_edith.conllu
# AMALGUM_fiction_una.conllu
# AMALGUM_fiction_tann.conllu
# AMALGUM_fiction_mates.conllu
# AMALGUM_fiction_van.conllu
# AMALGUM_fiction_rowley.conllu
# AMALGUM_fiction_wuthering.conllu
# AMALGUM_fiction_novel.conllu
# AMALGUM_fiction_bunner.conllu
# AMALGUM_fiction_prometheus.conllu
# AMALGUM_fiction_diameter.conllu
# AMALGUM_fiction_artagnan.conllu
# AMALGUM_fiction_eliakim.conllu
# AMALGUM_fiction_theron.conllu
# AMALGUM_fiction_cadignan.conllu
# AMALGUM_fiction_luck.conllu
# AMALGUM_fiction_brooding.conllu
# AMALGUM_fiction_mansfield.conllu
# AMALGUM_fiction_dugong.conllu
# AMALGUM_fiction_edie.conllu
# AMALGUM_fiction_fifth.conllu
# AMALGUM_fiction_potter.conllu
# AMALGUM_fiction_amulet.conllu
# AMALGUM_fiction_inga.conllu
# AMALGUM_fiction_mcchesney.conllu
# AMALGUM_fiction_bell.conllu
# AMALGUM_fiction_rode.conllu
# AMALGUM_fiction_golden.conllu
# AMALGUM_fiction_sage.conllu
# AMALGUM_fiction_thorne.conllu
# AMALGUM_fiction_grass.conllu
# AMALGUM_fiction_fanny.conllu
# AMALGUM_fiction_angus.conllu
# AMALGUM_fiction_sergius.conllu
# AMALGUM_fiction_jungle.conllu
# AMALGUM_fiction_hilda.conllu
# AMALGUM_fiction_romanticism.conllu
# AMALGUM_fiction_sis.conllu
# AMALGUM_fiction_anthem.conllu
# AMALGUM_fiction_canaan.conllu
# AMALGUM_fiction_sabethany.conllu
# AMALGUM_fiction_novelized.conllu
# AMALGUM_fiction_consciousness.conllu
# AMALGUM_fiction_indian.conllu
# AMALGUM_fiction_tirant.conllu
# AMALGUM_fiction_stairs.conllu
# AMALGUM_fiction_desplein.conllu
# AMALGUM_fiction_bradley.conllu
# AMALGUM_fiction_baartock.conllu
# AMALGUM_fiction_steam.conllu
# AMALGUM_fiction_howe.conllu
# AMALGUM_fiction_shadow.conllu
# AMALGUM_fiction_chuzzlewit.conllu
# AMALGUM_fiction_bud.conllu
# AMALGUM_fiction_heel.conllu
# AMALGUM_fiction_norman.conllu
# AMALGUM_fiction_holmes.conllu
# AMALGUM_fiction_catriona.conllu
# AMALGUM_fiction_curiosity.conllu
# AMALGUM_fiction_lightning.conllu
# AMALGUM_fiction_allan.conllu
# AMALGUM_fiction_fish.conllu
# AMALGUM_fiction_violists.conllu
# AMALGUM_fiction_horseman.conllu
# AMALGUM_fiction_conflict.conllu
# AMALGUM_fiction_genevieve.conllu
# AMALGUM_fiction_karenin.conllu
# AMALGUM_fiction_fang.conllu
# AMALGUM_fiction_beauty.conllu
# AMALGUM_fiction_professor.conllu
# AMALGUM_fiction_buck.conllu
# AMALGUM_fiction_ambrose.conllu
# AMALGUM_fiction_cedars.conllu
# AMALGUM_fiction_wickham.conllu
# AMALGUM_fiction_mitchell.conllu
# AMALGUM_fiction_madeline.conllu
# AMALGUM_fiction_persuasion.conllu
# AMALGUM_fiction_bhaer.conllu
# AMALGUM_fiction_flambeau.conllu
# AMALGUM_fiction_minded.conllu
# AMALGUM_fiction_grassou.conllu
# AMALGUM_fiction_jude.conllu
# AMALGUM_fiction_dope.conllu
# AMALGUM_fiction_beatrix.conllu
# AMALGUM_fiction_fawn.conllu
# AMALGUM_fiction_pan.conllu
# AMALGUM_fiction_lenape.conllu
# AMALGUM_fiction_pompey.conllu
# AMALGUM_fiction_zane.conllu
# AMALGUM_fiction_uncle.conllu
# AMALGUM_fiction_bessie.conllu
#
# Total words: 288742
# Total characters: 1438960

# %%
# Data Cleaning

def merge_apostrophe_tokens(tokens):
    merged_tokens = []
    i = 0
    while i < len(tokens):
        if i < len(tokens) - 1 and tokens[i+1].lower() in {
            "'s", "’s", "'re", "’re", "'ve", "’ve", "'ll", "’ll", "'d", "’d", "'m", "’m", "n't", "n’t"
        }:
            merged = tokens[i] + tokens[i+1]
            merged_tokens.append(merged)
            i += 2
        else:
            merged_tokens.append(tokens[i])
            i += 1
    return merged_tokens

def clean_token(token):
    token = token.lower()
    token = re.sub(r"^[^\w']+|[^\w']+$", "", token)
    if re.fullmatch(r"[a-zA-Z]+'[a-zA-Z]+", token) or token.isalpha():
        return token
    return ""

merged_tokens = merge_apostrophe_tokens(all_tokens)

cleaned_tokens = [clean_token(tok) for tok in merged_tokens if clean_token(tok)]
raw_clean_text = ' '.join(cleaned_tokens)

word_freq = Counter(cleaned_tokens)

# %%
# Data Analysis

total_words = sum(word_freq.values())
unique_words = len(word_freq)

freq_df = pd.DataFrame(word_freq.items(), columns=['word', 'count'])
freq_df['percent'] = (freq_df['count'] / total_words) * 100
freq_df = freq_df.sort_values(by='count', ascending=False).reset_index(drop=True)

df_size_kb = freq_df.memory_usage(deep=True).sum() / 1024
print(f"DataFrame size: {df_size_kb:.2f} KB")
print(f"Total words: {total_words}")
print(f"Unique words: {unique_words}")
print("\nTop 50 most common words:")
print(freq_df.head(50))
# Out:
# DataFrame size: 1818.61 KB
# Total words: 233241
# Unique words: 23057
#
# Top 50 most common words:
#      word  count   percent
# 0     the  14374  6.162724
# 1      of   8654  3.710325
# 2     and   8176  3.505387
# 3      to   5829  2.499132
# 4      in   5481  2.349930
# 5       a   5079  2.177576
# 6     was   3711  1.591058
# 7      he   3209  1.375830
# 8     his   2481  1.063707
# 9    that   2343  1.004540
# 10     as   1936  0.830043
# 11      i   1885  0.808177
# 12     it   1850  0.793171
# 13   with   1827  0.783310
# 14    for   1826  0.782881
# 15     on   1669  0.715569
# 16    had   1595  0.683842
# 17    she   1547  0.663262
# 18    her   1514  0.649114
# 19     at   1392  0.596808
# 20     is   1265  0.542357
# 21     by   1187  0.508916
# 22    you   1108  0.475045
# 23   from   1067  0.457467
# 24    but   1051  0.450607
# 25    not    934  0.400444
# 26     be    910  0.390154
# 27    him    864  0.370432
# 28   they    854  0.366145
# 29     an    841  0.360571
# 30  which    795  0.340849
# 31   were    788  0.337848
# 32   have    767  0.328844
# 33    one    725  0.310837
# 34   this    715  0.306550
# 35    all    663  0.284255
# 36    who    660  0.282969
# 37     so    622  0.266677
# 38     or    622  0.266677
# 39   when    606  0.259817
# 40   said    589  0.252529
# 41   been    571  0.244811
# 42  their    546  0.234093
# 43  there    539  0.231091
# 44     my    537  0.230234
# 45     no    521  0.223374
# 46  would    467  0.200222
# 47   them    466  0.199793
# 48     me    448  0.192076
# 49    out    434  0.186074

# %%
# Save Data to Drive

from google.colab import drive
drive.mount('/content/drive')

output_path = "/content/drive/MyDrive/NWP/cleaned_text.txt"

with open(output_path, "w", encoding="utf-8") as f:
    f.write(raw_clean_text)

print(f"Saved cleaned text to: {output_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Saved cleaned text to: /content/drive/MyDrive/NWP/cleaned_text.txt
